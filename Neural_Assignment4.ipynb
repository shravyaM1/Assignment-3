# %% [markdown]
# <a href="https://colab.research.google.com/github/shravyaM1/Assignment-3/blob/main/Neural_Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Read the CSV file
data = pd.read_csv('data.csv')

# Show basic statistical description
description = data.describe()

# Check for null values and replace with mean
data.fillna(data.mean(), inplace=True)

# Select at least two columns and aggregate the data
agg_data = data[['Calories', 'Duration']].agg(['min', 'max', 'count', 'mean'])

# Filter rows with calories values between 500 and 1000
filtered_data1 = data[(data['Calories'] >= 500) & (data['Calories'] <= 1000)]

# Filter rows with calories > 500 and pulse < 100
filtered_data2 = data[(data['Calories'] > 500) & (data['Pulse'] < 100)]

# Create a new dataframe without "Maxpulse" column
df_modified = data.drop(columns=['Maxpulse'])

# Delete the "Maxpulse" column from the main dataframe
data.drop(columns=['Maxpulse'], inplace=True)

# Convert the datatype of "Calories" column to int
data['Calories'] = data['Calories'].astype(int)

# Create a scatter plot for Duration and Calories
import matplotlib.pyplot as plt
plt.scatter(data['Duration'], data['Calories'])
plt.xlabel('Duration')
plt.ylabel('Calories')
plt.title('Scatter Plot: Duration vs. Calories')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Step 1: Import the dataset
data = pd.read_csv('Salary_Data.csv')

# Step 2: Split the data into train and test partitions
X = data[['YearsExperience']]  # Features (independent variable)
y = data['Salary']  # Target (dependent variable)

# Split the data into 2/3 train and 1/3 test subsets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=42)

# Step 3: Train and predict the model
model = LinearRegression()
model.fit(X_train, y_train)  # Training the model
y_pred_train = model.predict(X_train)  # Predicting on the train data
y_pred_test = model.predict(X_test)    # Predicting on the test data

# Step 4: Calculate the mean squared error (MSE)
mse_train = mean_squared_error(y_train, y_pred_train)
mse_test = mean_squared_error(y_test, y_pred_test)

print("Mean Squared Error (Train):", mse_train)
print("Mean Squared Error (Test):", mse_test)

# Step 5: Visualize both train and test data using a scatter plot
plt.scatter(X_train, y_train, color='blue', label='Train Data')
plt.scatter(X_test, y_test, color='red', label='Test Data')
plt.plot(X_train, y_pred_train, color='green', label='Regression Line (Train)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs. Years of Experience')
plt.legend()
plt.show()
# Out:
# Mean Squared Error (Train): 29793161.082422983
# Mean Squared Error (Test): 35301898.887134895
